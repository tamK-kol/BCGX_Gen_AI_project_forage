# %% [markdown]
# ### How to use this AI-powered Financial Chatbot: Use these below queries for results. For better understanding check the 'user_guide' file.
#
# * total revenue
#
# * net income
#
# * sum of total assets
#
# * sum of total liabilities
#
# * cash flow from operating activities
#
# * revenue growth(%)
#
# * net income growth(%)
#
# * assets growth(%)
#
# * liabilities growth(%)
#
# * cash flow from operations growth(%)
#
# * year by year average revenue growth rate(%)
#
# * year by year average net income growth rate(%)
#
# * year by year average assets growth rate(%)
#
# * year by year average liabilities growth rate(%)
#
# * year by year average cash flow from operations growth rate(%)

# %%
import pandas as pd

# Load the datasets
trends_data = pd.read_csv('trends_data.csv')
summary_trends_data = pd.read_csv('summary_trends_data.csv')

# %%
# Set pandas to display float numbers in standard notation
pd.options.display.float_format = '{:.2f}'.format
trends_data
# Out:
#    Unnamed: 0    Company  Fiscal Year   Total Revenue     Net Income  \
# 0           0  Microsoft         2021 168088000000.00 61271000000.00
# 1           1  Microsoft         2022 202825000000.00 66404000000.00
# 2           2  Microsoft         2023 261162000000.00 89132000000.00
# 3           3      Tesla         2021  31536000000.00   721000000.00
# 4           4      Tesla         2022  56186000000.00  1775000000.00
# 5           5      Tesla         2023  98027000000.00  6663000000.00
# 6           6      Apple         2021 347160000000.00 74010000000.00
# 7           7      Apple         2022 365720000000.00 86040000000.00
# 8           8      Apple         2023 383910000000.00 92360000000.00
#
#      Total Assets  Total Liabilities  Cash Flow from Operating Activities  \
# 0 301311000000.00    176130000000.00                       76903000000.00
# 1 365945000000.00    215019000000.00                       82693000000.00
# ...

# %%
summary_trends_data
# Out:
#    Unnamed: 0    Company  Revenue Growth (%)  Net Income Growth (%)  \
# 0           0      Apple                5.16                  11.80
# 1           1  Microsoft               24.71                  21.30
# 2           2      Tesla               76.32                 210.78
#
#    Assets Growth (%)  Liabilities Growth (%)  Cash Flow Growth (%)
# 0               8.25                    8.76                 10.14
# 1              23.09                   22.96                 17.64
# 2              69.85                   70.59                 48.24
